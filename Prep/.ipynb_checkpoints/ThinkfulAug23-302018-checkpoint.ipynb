# %%
import pandas as pd
import statistics
import numpy as np
fifa18 = pd.read_csv("fifa-18-demo-player-dataset/fifa18.csv")
statistics.mode(df['Age'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (23,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 25

# %%
# Generate a list of unique elements along with how often they occur.
(values, counts) = np.unique(df['Age'], return_counts=True)
freq = dict()
for i in range(len(values)):
    freq[values[i]] = counts[i]
#print(freq)
# The location in the values list of the most-frequently-occurring element.
#ind = np.argmax(counts)
indices = np.where(counts == np.max(counts))
print(indices)
# The most frequent element.
#print(values[ind])
# Out:
# (array([9], dtype=int64),)

# %%
# Generate a list of unique elements along with how often they occur.
(values, counts) = np.unique([1,1,3,3,4,5,6], return_counts=True)
#freq = dict()
#for i in range(len(values)):
#    freq[values[i]] = counts[i]
#print(freq)
# The location in the values list of the most-frequently-occurring element.
max = np.max(counts)

indices = np.argwhere(counts == max)
print(indices)
# The most frequent element.
#print(values[ind])

#sorted(counts)
# Out:
# [[0]
#  [1]]

# %% [markdown]
# #### Cleaning Wage and Value

# %% [markdown]
# I converted "Value" and "Wage" columns from String to float.
# * Cut out the currency symbol
# * Multiplied by the prefixes accordingly
#
# *** M = 1e6
#
# *** K = 1e3
#
# €95.5M will be 95500000
#
# €4.1K will be 4100
#
# €0 will be 0.

# %%
#This operation took more than 5 minutes
#for i, v in enumerate(df['Value']):
#    if('M' in v):
#        df['Value'][i] = float(df['Value'][i][1:-1]) * 1e6
#    elif('K' in v):
#        df['Value'][i] = float(df['Value'][i][1:-1]) * 1e3
#    else:
#        df['Value'][i] = float(df['Value'][i][1:])
#df.to_csv("fifa18_mod1.csv")

# %%
#for i, w in enumerate(df['Wage']):
#    if('K' in w):
#        df['Wage'][i] = float(df['Wage'][i][1:-1]) * 1e3
#    elif('€0' in w):
#        df['Wage'][i] = float(df['Wage'][i][1:])     
#df.to_csv("fifa18_mod2.csv")

# %%
print(df['Wage'].std())
print(np.std(df['Wage'], ddof=1))
# Out:
# 23080.000138571682
# 23080.000138571682

# %%
# First, create an empty dataframe to store your variables-to-be.
pop=pd.DataFrame()

# Then create two variables with mean = 60, one with a low standard
# deviation (sd=10) and one with a high standard deviation (sd=100).
pop['low_var']=np.random.normal(60, 10, 10000)
pop['high_var']=np.random.normal(60, 100, 10000)

# Finally, create histograms of the two variables.
pop.hist(layout=(2, 1), sharex=True)
plt.show()

# Calculate and print the maximum and minimum values for each variable.
print(pop.max())
print(pop.min())
# Out:
# low_var      94.563769
# high_var    477.053276
# dtype: float64
# low_var      21.45140
# high_var   -330.17361
# dtype: float64

# %%
# Take a random sample of 100 observations from each variable
# and store it in a new dataframe.
sample=pd.DataFrame()
sample['low_var'] = np.random.choice(pop['low_var'], 100)
sample['high_var']=np.random.choice(pop['high_var'], 100)

# Again, visualize the data. Note that here we're using a pandas method to 
# create the histogram.
sample.hist()
plt.show()

# Check how well the sample replicates the population.
#print(sample.mean()
print(sample.std(ddof=1))
# Out:
# low_var     10.174719
# high_var    97.648906
# dtype: float64

# %%
fifa18[fifa18['Name'].str.contains("Buffon") == True]
# Out:
#     Unnamed: 0       Name  Age                                          Photo  \
# 18          18  G. Buffon   39  https://cdn.sofifa.org/48/18/players/1179.png
#
#    Nationality                                 Flag  Overall  Potential  \
# 18       Italy  https://cdn.sofifa.org/flags/27.png       89         89
#
#         Club                                  Club Logo ...  RB RCB  RCM RDM  \
# 18  Juventus  https://cdn.sofifa.org/24/18/teams/45.png ... NaN NaN  NaN NaN
#
#     RF  RM  RS  RW RWB  ST
# 18 NaN NaN NaN NaN NaN NaN
#
# [1 rows x 75 columns]

# %% [markdown]
# Lesson 3: Statistics for data science

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Set up the data
data = pd.DataFrame()
data['gender'] = ['male'] * 100 + ['female'] * 100
data['height'] = np.append(np.random.normal(69, 8, 100), np.random.normal(64, 5, 100))
data['weight'] = np.append(np.random.normal(195, 25, 100), np.random.normal(166, 15, 100))

# %%
print(data.height.mean())
print(data[data['gender'] == 'female']['height'].mean())
print(data[data['gender'] == 'male']['height'].mean())
# Out:
# 65.86858437350148
# 63.50449436646825
# 68.23267438053463

# %%
plt.hist(data[data['gender'] == 'male']['height'], histtype = "stepfilled", density = True)
plt.show()

# %%
plt.hist?

# %%
fifa18['Age'].describe()
# Out:
# count    17981.000000
# mean        25.144541
# std          4.614272
# min         16.000000
# 25%         21.000000
# 50%         25.000000
# 75%         28.000000
# max         47.000000
# Name: Age, dtype: float64

# %%
fifa18.groupby('Club').describe()
# Out:
#                            Age                                                 \
#                          count       mean       std   min    25%   50%    75%
# Club
#  SSV Jahn Regensburg      28.0  24.571429  3.735997  20.0  21.75  24.0  27.00
# 1. FC Heidenheim          26.0  24.615385  3.710277  18.0  22.00  24.5  27.75
# 1. FC Kaiserslautern      29.0  22.620690  3.488899  17.0  19.00  22.0  25.00
# 1. FC Köln                30.0  24.166667  4.202490  17.0  21.00  24.5  27.00
# 1. FC Magdeburg           25.0  25.200000  4.582576  17.0  21.00  24.0  29.00
# 1. FC Nürnberg            28.0  24.714286  3.998677  20.0  21.75  23.0  28.00
# 1. FC Union Berlin        27.0  25.370370  4.541672  17.0  22.00  26.0  28.50
# 1. FSV Mainz 05           30.0  24.200000  3.428079  19.0  22.00  23.5  26.75
# AC Ajaccio                24.0  25.375000  5.223796  17.0  21.00  24.0  31.00
# AC Horsens                24.0  24.166667  4.824455  18.0  20.75  23.5  26.25
# ...

# %%
mydf = data.groupby('gender').describe()
mydf.height.loc[['female'], ['count']]
# Out:
#         count
# gender
# female  100.0

# %%
type(data.gender.value_counts())
# Out:
# pandas.core.series.Series

# %%
fifa18.Club.index
# Out:
# RangeIndex(start=0, stop=17981, step=1)

# %%
data.groupby('gender').describe()
# Out:
#        height                                                                  \
#         count       mean       std       min        25%        50%        75%
# gender
# female  100.0  63.504494  4.970794  51.16114  60.291184  63.495670  66.343200
# male    100.0  68.232674  9.042062  44.61722  63.354008  67.889347  73.890347
#
#                   weight                                                 \
#               max  count        mean        std         min         25%
# gender
# female  74.001090  100.0  167.455081  16.887144  128.318136  156.965096
# male    90.471316  100.0  193.679017  23.262564  116.831350  184.692416
#
#
#                50%         75%         max
# gender
# female  166.892737  177.234169  207.472399
# male    196.161382  209.130128  248.207417
